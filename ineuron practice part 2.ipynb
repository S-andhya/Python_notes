# %%
import pandas as pd

# %%
df =pd.read_csv('https://gist.githubusercontent.com/DariaAlekseeva/299611a0daa6008685f7/raw/b431eb200bcafd2eba68a11ccbc80d051d3eeba9/titanic.csv')

# %%
df.head(2)
# Out:
#    PassengerId Passengers  Class  \
# 0            1   Perished      3
# 1            2   Survived      1
#
#                                                 Name     Sex      Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  19 - 40      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  19 - 40      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(2)
# Out:
#       PassengerId Passengers  Class                          Name     Sex  \
# 1044         1306   Survived      1  Oliva y Ocana, Dona. Fermina  female
# 1045         1307   Perished      3  Saether, Mr. Simon Sivertsen    male
#
#           Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 1044  19 - 40      0      0            PC 17758  108.90  C105        C
# 1045  19 - 40      0      0  SOTON/O.Q. 3101262    7.25   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Passengers      object
# Class            int64
# Name            object
# Sex             object
# Age             object
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes=='object' #==is comparision operatoe and =is assignment operator
# if you want to assign some values then use single = sign.
# if you want to compare something then use == sign.
# Out:
# PassengerId    False
# Passengers      True
# Class          False
# Name            True
# Sex             True
# Age             True
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Passengers    object
# Name          object
# Sex           object
# Age           object
# Ticket        object
# Cabin         object
# Embarked      object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Passengers', 'Name', 'Sex', 'Age', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[['Name','Sex','Age']]# you can fetch the columns manually but 
#in case of thousand column below code is better to use.
# Out:
#                                                    Name     Sex       Age
# 0                               Braund, Mr. Owen Harris    male   19 - 40
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female   19 - 40
# 2                                Heikkinen, Miss. Laina  female   19 - 40
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   19 - 40
# 4                              Allen, Mr. William Henry    male   19 - 40
# 5                               McCarthy, Mr. Timothy J    male   Over 40
# 6                        Palsson, Master. Gosta Leonard    male  Under 18
# 7     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   19 - 40
# 8                   Nasser, Mrs. Nicholas (Adele Achem)  female  Under 18
# 9                       Sandstrom, Miss. Marguerite Rut  female  Under 18
# 10                             Bonnell, Miss. Elizabeth  female   Over 40
# 11                       Saundercock, Mr. William Henry    male   19 - 40
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#      Passengers                                               Name     Sex  \
# 0      Perished                            Braund, Mr. Owen Harris    male
# 1      Survived  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2      Survived                             Heikkinen, Miss. Laina  female
# 3      Survived       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4      Perished                           Allen, Mr. William Henry    male
# 5      Perished                            McCarthy, Mr. Timothy J    male
# 6      Perished                     Palsson, Master. Gosta Leonard    male
# 7      Survived  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 8      Survived                Nasser, Mrs. Nicholas (Adele Achem)  female
# 9      Survived                    Sandstrom, Miss. Marguerite Rut  female
# 10     Survived                           Bonnell, Miss. Elizabeth  female
# ...

# %%
df[df.dtypes[df.dtypes=='int64'].index]
# Out:
#       PassengerId  Class  SibSp  Parch
# 0               1      3      1      0
# 1               2      1      1      0
# 2               3      3      0      0
# 3               4      1      1      0
# 4               5      3      0      0
# 5               7      1      0      0
# 6               8      3      3      1
# 7               9      3      0      2
# 8              10      2      1      0
# 9              11      3      1      1
# 10             12      1      0      0
# 11             13      3      0      0
# 12             14      3      1      5
# 13             15      3      0      0
# 14             16      2      0      0
# 15             17      3      4      1
# 16             19      3      1      0
# 17             21      2      0      0
# 18             22      2      0      0
# 19             23      3      0      0
# 20             24      1      0      0
# 21             25      3      3      1
# 22             26      3      1      5
# ...

# %%
#if we want to fetch multiple conditions together
df[df.dtypes[(df.dtypes=='float64')|(df.dtypes=='int64')].index]
# Out:
#       PassengerId  Class  SibSp  Parch      Fare
# 0               1      3      1      0    7.2500
# 1               2      1      1      0   71.2833
# 2               3      3      0      0    7.9250
# 3               4      1      1      0   53.1000
# 4               5      3      0      0    8.0500
# 5               7      1      0      0   51.8625
# 6               8      3      3      1   21.0750
# 7               9      3      0      2   11.1333
# 8              10      2      1      0   30.0708
# 9              11      3      1      1   16.7000
# 10             12      1      0      0   26.5500
# 11             13      3      0      0    8.0500
# 12             14      3      1      5   31.2750
# 13             15      3      0      0    7.8542
# 14             16      2      0      0   16.0000
# 15             17      3      4      1   29.1250
# 16             19      3      1      0   18.0000
# 17             21      2      0      0   26.0000
# ...

# %%
df
# Out:
#       PassengerId Passengers  Class  \
# 0               1   Perished      3
# 1               2   Survived      1
# 2               3   Survived      3
# 3               4   Survived      1
# 4               5   Perished      3
# 5               7   Perished      1
# 6               8   Perished      3
# 7               9   Survived      3
# 8              10   Survived      2
# 9              11   Survived      3
# 10             12   Survived      1
# 11             13   Perished      3
# 12             14   Perished      3
# 13             15   Perished      3
# 14             16   Survived      2
# 15             17   Perished      3
# 16             19   Perished      3
# 17             21   Perished      2
# 18             22   Survived      2
# 19             23   Survived      3
# 20             24   Survived      1
# 21             25   Perished      3
# 22             26   Survived      3
# 23             28   Perished      1
# 24             31   Perished      1
# ...

# %%
df.describe()
# Out:
#        PassengerId        Class        SibSp       Parch         Fare
# count  1046.000000  1046.000000  1046.000000  1046.00000  1045.000000
# mean    655.362333     2.207457     0.502868     0.42065    36.686080
# std     377.661401     0.841497     0.912167     0.83975    55.732533
# min       1.000000     1.000000     0.000000     0.00000     0.000000
# 25%     326.250000     1.000000     0.000000     0.00000     8.050000
# 50%     662.500000     2.000000     0.000000     0.00000    15.750000
# 75%     973.750000     3.000000     1.000000     1.00000    35.500000
# max    1307.000000     3.000000     8.000000     6.00000   512.329200

# %%
#25% percentile or 50% percentile or 75% percentile means
#suppose i have a list of [1,2,3,4,1,2,3,4]
# arrange in ascending order[1,1,2,2,3,3,4,5]
# total no. of elements in the list is 8
#25%percentile means 25% of 8 =2 means the second position 1
# 75% percentile means 75% of 8 =6 means the sixth position which is 3
# 50%percentile means 50% of 8 =4 means fourth position 2

# %%
# describe function is not showing except numerical data.
# That's why it's not used frequently
df1=df[df.dtypes[df.dtypes=='object'].index]

# %%
df1.describe()
# Out:
#        Passengers                  Name   Sex      Age   Ticket        Cabin  \
# count        1046                  1046  1046     1046     1046          272
# unique          2                  1044     2        3      732          174
# top      Perished  Connolly, Miss. Kate  male  19 - 40  CA 2144  C23 C25 C27
# freq          635                     2   658      626        8            6
#
#        Embarked
# count      1044
# unique        3
# top           S
# freq        782

# %%
df.columns
# Out:
# Index(['PassengerId', 'Passengers', 'Class', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name'][0:5:1]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df
# Out:
#       PassengerId Passengers  Class  \
# 0               1   Perished      3
# 1               2   Survived      1
# 2               3   Survived      3
# 3               4   Survived      1
# 4               5   Perished      3
# 5               7   Perished      1
# 6               8   Perished      3
# 7               9   Survived      3
# 8              10   Survived      2
# 9              11   Survived      3
# 10             12   Survived      1
# 11             13   Perished      3
# 12             14   Perished      3
# 13             15   Perished      3
# 14             16   Survived      2
# 15             17   Perished      3
# 16             19   Perished      3
# 17             21   Perished      2
# 18             22   Survived      2
# 19             23   Survived      3
# 20             24   Survived      1
# 21             25   Perished      3
# 22             26   Survived      3
# 23             28   Perished      1
# 24             31   Perished      1
# ...

# %%
df['sudh']='kumar'
df
# Out:
#       PassengerId Passengers  Class  \
# 0               0   Perished      3
# 1               0   Survived      1
# 2               0   Survived      3
# 3               0   Survived      1
# 4               0   Perished      3
# 5               0   Perished      1
# 6               0   Perished      3
# 7               0   Survived      3
# 8               0   Survived      2
# 9               0   Survived      3
# 10              0   Survived      1
# 11              0   Perished      3
# 12              0   Perished      3
# 13              0   Perished      3
# 14              0   Survived      2
# 15              0   Perished      3
# 16              0   Perished      3
# 17              0   Perished      2
# 18              0   Survived      2
# 19              0   Survived      3
# 20              0   Survived      1
# 21              0   Perished      3
# 22              0   Survived      3
# 23              0   Perished      1
# 24              0   Perished      1
# ...

# %%
df['PassengerId']=0

# %%
df
# Out:
#       PassengerId Passengers  Class  \
# 0               0   Perished      3
# 1               0   Survived      1
# 2               0   Survived      3
# 3               0   Survived      1
# 4               0   Perished      3
# 5               0   Perished      1
# 6               0   Perished      3
# 7               0   Survived      3
# 8               0   Survived      2
# 9               0   Survived      3
# 10              0   Survived      1
# 11              0   Perished      3
# 12              0   Perished      3
# 13              0   Perished      3
# 14              0   Survived      2
# 15              0   Perished      3
# 16              0   Perished      3
# 17              0   Perished      2
# 18              0   Survived      2
# 19              0   Survived      3
# 20              0   Survived      1
# 21              0   Perished      3
# 22              0   Survived      3
# 23              0   Perished      1
# 24              0   Perished      1
# ...

# %%
import numpy as np

# %%
row_index_not_null=np.where(df['Age'].isnull()==False)

# %%
df.head(3)
# Out:
#    PassengerId Passengers  Class  \
# 0            0   Perished      3
# 1            0   Survived      1
# 2            0   Survived      3
#
#                                                 Name     Sex      Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  19 - 40      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  19 - 40      1
# 2                             Heikkinen, Miss. Laina  female  19 - 40      0
#
#    Parch            Ticket     Fare Cabin Embarked  xyz   sudh
# 0      0         A/5 21171   7.2500   NaN        S    4  kumar
# 1      0          PC 17599  71.2833   C85        C    2  kumar
# 2      0  STON/O2. 3101282   7.9250   NaN        S    3  kumar

# %%
df.iloc[[0,3,5]]# integer location(iloc) is to fetch rows
# Out:
#    PassengerId Passengers  Class  \
# 0            0   Perished      3
# 3            0   Survived      1
# 5            0   Perished      1
#
#                                            Name     Sex      Age  SibSp  \
# 0                       Braund, Mr. Owen Harris    male  19 - 40      1
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  19 - 40      1
# 5                       McCarthy, Mr. Timothy J    male  Over 40      0
#
#    Parch     Ticket     Fare Cabin Embarked  xyz   sudh
# 0      0  A/5 21171   7.2500   NaN        S    4  kumar
# 3      0     113803  53.1000  C123        S    2  kumar
# 5      0      17463  51.8625   E46        S    1  kumar

# %%
df.iloc[row_index_not_null]
# Out:
#       PassengerId Passengers  Class  \
# 0               0   Perished      3
# 1               0   Survived      1
# 2               0   Survived      3
# 3               0   Survived      1
# 4               0   Perished      3
# 5               0   Perished      1
# 6               0   Perished      3
# 7               0   Survived      3
# 8               0   Survived      2
# 9               0   Survived      3
# 10              0   Survived      1
# 11              0   Perished      3
# 12              0   Perished      3
# 13              0   Perished      3
# 14              0   Survived      2
# 15              0   Perished      3
# 16              0   Perished      3
# 17              0   Perished      2
# 18              0   Survived      2
# 19              0   Survived      3
# 20              0   Survived      1
# 21              0   Perished      3
# 22              0   Survived      3
# 23              0   Perished      1
# 24              0   Perished      1
# ...

# %%
df.iloc[row_index_not_null]['Name']
# Out:
# 0                                 Braund, Mr. Owen Harris
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                  Heikkinen, Miss. Laina
# 3            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                                Allen, Mr. William Henry
# 5                                 McCarthy, Mr. Timothy J
# 6                          Palsson, Master. Gosta Leonard
# 7       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8                     Nasser, Mrs. Nicholas (Adele Achem)
# 9                         Sandstrom, Miss. Marguerite Rut
# 10                               Bonnell, Miss. Elizabeth
# 11                         Saundercock, Mr. William Henry
# 12                            Andersson, Mr. Anders Johan
# 13                   Vestrom, Miss. Hulda Amanda Adolfina
# 14                       Hewlett, Mrs. (Mary D Kingcome)
# 15                                   Rice, Master. Eugene
# ...

# %%
df.iloc[row_index_not_null][['Name']]
# Out:
#                                                    Name
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                               McCarthy, Mr. Timothy J
# 6                        Palsson, Master. Gosta Leonard
# 7     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8                   Nasser, Mrs. Nicholas (Adele Achem)
# 9                       Sandstrom, Miss. Marguerite Rut
# 10                             Bonnell, Miss. Elizabeth
# 11                       Saundercock, Mr. William Henry
# 12                          Andersson, Mr. Anders Johan
# 13                 Vestrom, Miss. Hulda Amanda Adolfina
# 14                     Hewlett, Mrs. (Mary D Kingcome)
# 15                                 Rice, Master. Eugene
# ...

# %%
np.where(df['Fare']==max(df['Fare']))
# Out:
# (array([208, 537, 587, 984], dtype=int64),)

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df.iloc[np.where(df['Fare']==max(df['Fare']))]
# Out:
#      PassengerId Passengers  Class  \
# 208            0   Survived      1
# 537            0   Survived      1
# 587            0   Survived      1
# 984            0   Survived      1
#
#                                                   Name     Sex      Age  \
# 208                                   Ward, Miss. Anna  female  19 - 40
# 537                 Cardeza, Mr. Thomas Drake Martinez    male  19 - 40
# 587                             Lesurer, Mr. Gustave J    male  19 - 40
# 984  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  Over 40
#
#      SibSp  Parch    Ticket      Fare        Cabin Embarked  xyz   sudh
# 208      0      0  PC 17755  512.3292          NaN        C    1  kumar
# 537      0      1  PC 17755  512.3292  B51 B53 B55        C    1  kumar
# 587      0      0  PC 17755  512.3292         B101        C    1  kumar
# 984      0      1  PC 17755  512.3292  B51 B53 B55        C    1  kumar

# %%
df.iloc[np.where(df['Fare']==max(df['Fare']))][['Name','Age']]
# Out:
#                                                   Name      Age
# 208                                   Ward, Miss. Anna  19 - 40
# 537                 Cardeza, Mr. Thomas Drake Martinez  19 - 40
# 587                             Lesurer, Mr. Gustave J  19 - 40
# 984  Cardeza, Mrs. James Warburton Martinez (Charlo...  Over 40

# %%
df.iloc[np.where(df['Sex']=='male')]
# Out:
#       PassengerId Passengers  Class  \
# 0               0   Perished      3
# 4               0   Perished      3
# 5               0   Perished      1
# 6               0   Perished      3
# 11              0   Perished      3
# 12              0   Perished      3
# 15              0   Perished      3
# 17              0   Perished      2
# 18              0   Survived      2
# 20              0   Survived      1
# 23              0   Perished      1
# 24              0   Perished      1
# 25              0   Perished      2
# 26              0   Perished      1
# 27              0   Perished      1
# 28              0   Perished      3
# 36              0   Perished      3
# 37              0   Perished      3
# 40              0   Perished      1
# 42              0   Perished      3
# 44              0   Perished      3
# 45              0   Perished      3
# 47              0   Perished      1
# 48              0   Perished      3
# 50              0   Perished      3
# ...

# %%
df[(df['SibSp']==0) &(df['Cabin']=='E46')]
# Out:
#    PassengerId Passengers  Class                     Name   Sex      Age  \
# 5            0   Perished      1  McCarthy, Mr. Timothy J  male  Over 40
#
#    SibSp  Parch Ticket     Fare Cabin Embarked  xyz   sudh
# 5      0      0  17463  51.8625   E46        S    1  kumar

# %%
df.head()
# Out:
#    PassengerId Passengers  Class  \
# 0            0   Perished      3
# 1            0   Survived      1
# 2            0   Survived      3
# 3            0   Survived      1
# 4            0   Perished      3
#
#                                                 Name     Sex      Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  19 - 40      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  19 - 40      1
# 2                             Heikkinen, Miss. Laina  female  19 - 40      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  19 - 40      1
# 4                           Allen, Mr. William Henry    male  19 - 40      0
#
#    Parch            Ticket     Fare Cabin Embarked  xyz   sudh
# 0      0         A/5 21171   7.2500   NaN        S    4  kumar
# 1      0          PC 17599  71.2833   C85        C    2  kumar
# 2      0  STON/O2. 3101282   7.9250   NaN        S    3  kumar
# ...

# %%
df['xyz']=df['Class']+df['SibSp']

# %%
df
# Out:
#       PassengerId Passengers  Class  \
# 0               0   Perished      3
# 1               0   Survived      1
# 2               0   Survived      3
# 3               0   Survived      1
# 4               0   Perished      3
# 5               0   Perished      1
# 6               0   Perished      3
# 7               0   Survived      3
# 8               0   Survived      2
# 9               0   Survived      3
# 10              0   Survived      1
# 11              0   Perished      3
# 12              0   Perished      3
# 13              0   Perished      3
# 14              0   Survived      2
# 15              0   Perished      3
# 16              0   Perished      3
# 17              0   Perished      2
# 18              0   Survived      2
# 19              0   Survived      3
# 20              0   Survived      1
# 21              0   Perished      3
# 22              0   Survived      3
# 23              0   Perished      1
# 24              0   Perished      1
# ...

# %%
df.iloc[np.where(df['Age']==max(df['Age']))]
# Out:
#       PassengerId Passengers  Class  \
# 6               0   Perished      3
# 8               0   Survived      2
# 9               0   Survived      3
# 13              0   Perished      3
# 15              0   Perished      3
# 19              0   Survived      3
# 21              0   Perished      3
# 29              0   Perished      3
# 30              0   Survived      3
# 33              0   Survived      2
# 35              0   Perished      3
# 36              0   Perished      3
# 43              0   Survived      2
# 44              0   Perished      3
# 48              0   Perished      3
# 51              0   Survived      3
# 54              0   Perished      3
# 59              0   Survived      2
# 64              0   Survived      2
# 66              0   Perished      3
# 86              0   Perished      3
# 89              0   Perished      3
# 94              0   Perished      3
# 99              0   Survived      3
# 110             0   Perished      3
# ...

# %%
df[df['Age']==df['Age'].max()]
# Out:
#       PassengerId Passengers  Class  \
# 6               0   Perished      3
# 8               0   Survived      2
# 9               0   Survived      3
# 13              0   Perished      3
# 15              0   Perished      3
# 19              0   Survived      3
# 21              0   Perished      3
# 29              0   Perished      3
# 30              0   Survived      3
# 33              0   Survived      2
# 35              0   Perished      3
# 36              0   Perished      3
# 43              0   Survived      2
# 44              0   Perished      3
# 48              0   Perished      3
# 51              0   Survived      3
# 54              0   Perished      3
# 59              0   Survived      2
# 64              0   Survived      2
# 66              0   Perished      3
# 86              0   Perished      3
# 89              0   Perished      3
# 94              0   Perished      3
# 99              0   Survived      3
# 110             0   Perished      3
# ...

# %%
# in order to delete some rows
df.drop('sudh',axis=1)
# Out:
#       PassengerId Passengers  Class  \
# 0               0   Perished      3
# 1               0   Survived      1
# 2               0   Survived      3
# 3               0   Survived      1
# 4               0   Perished      3
# 5               0   Perished      1
# 6               0   Perished      3
# 7               0   Survived      3
# 8               0   Survived      2
# 9               0   Survived      3
# 10              0   Survived      1
# 11              0   Perished      3
# 12              0   Perished      3
# 13              0   Perished      3
# 14              0   Survived      2
# 15              0   Perished      3
# 16              0   Perished      3
# 17              0   Perished      2
# 18              0   Survived      2
# 19              0   Survived      3
# 20              0   Survived      1
# 21              0   Perished      3
# 22              0   Survived      3
# 23              0   Perished      1
# 24              0   Perished      1
# ...

# %%
df
# Out:
#       PassengerId Passengers  Class  \
# 0               0   Perished      3
# 1               0   Survived      1
# 2               0   Survived      3
# 3               0   Survived      1
# 4               0   Perished      3
# 5               0   Perished      1
# 6               0   Perished      3
# 7               0   Survived      3
# 8               0   Survived      2
# 9               0   Survived      3
# 10              0   Survived      1
# 11              0   Perished      3
# 12              0   Perished      3
# 13              0   Perished      3
# 14              0   Survived      2
# 15              0   Perished      3
# 16              0   Perished      3
# 17              0   Perished      2
# 18              0   Survived      2
# 19              0   Survived      3
# 20              0   Survived      1
# 21              0   Perished      3
# 22              0   Survived      3
# 23              0   Perished      1
# 24              0   Perished      1
# ...

# %%
#since in upper code column 'sudh' was not permanently deleted
# So we need to use inplace=True to delete the row permanently
df.drop('sudh',axis=1,inplace=True)

# %%
df
# Out:
#       PassengerId Passengers  Class  \
# 0               0   Perished      3
# 1               0   Survived      1
# 2               0   Survived      3
# 3               0   Survived      1
# 4               0   Perished      3
# 5               0   Perished      1
# 6               0   Perished      3
# 7               0   Survived      3
# 8               0   Survived      2
# 9               0   Survived      3
# 10              0   Survived      1
# 11              0   Perished      3
# 12              0   Perished      3
# 13              0   Perished      3
# 14              0   Survived      2
# 15              0   Perished      3
# 16              0   Perished      3
# 17              0   Perished      2
# 18              0   Survived      2
# 19              0   Survived      3
# 20              0   Survived      1
# 21              0   Perished      3
# 22              0   Survived      3
# 23              0   Perished      1
# 24              0   Perished      1
# ...

# %%
df.drop(['Passengers','xyz'],axis=1,inplace=True)

# %%
df
# Out:
#       PassengerId  Class                                               Name  \
# 0               0      3                            Braund, Mr. Owen Harris
# 1               0      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               0      3                             Heikkinen, Miss. Laina
# 3               0      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               0      3                           Allen, Mr. William Henry
# 5               0      1                            McCarthy, Mr. Timothy J
# 6               0      3                     Palsson, Master. Gosta Leonard
# 7               0      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8               0      2                Nasser, Mrs. Nicholas (Adele Achem)
# 9               0      3                    Sandstrom, Miss. Marguerite Rut
# 10              0      1                           Bonnell, Miss. Elizabeth
# ...

# %%
# axis =0 means row and axis = 1 means column
# if I want to delete first index values
df.drop(1,axis=0,inplace=True)
#if I don't use axis=0 then also no problem
#because by default it's axis =0 
#otherwise see by clicking shift and tab

# %%
df
# Out:
#       PassengerId  Class                                               Name  \
# 0               0      3                            Braund, Mr. Owen Harris
# 2               0      3                             Heikkinen, Miss. Laina
# 3               0      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               0      3                           Allen, Mr. William Henry
# 5               0      1                            McCarthy, Mr. Timothy J
# 6               0      3                     Palsson, Master. Gosta Leonard
# 7               0      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8               0      2                Nasser, Mrs. Nicholas (Adele Achem)
# 9               0      3                    Sandstrom, Miss. Marguerite Rut
# 10              0      1                           Bonnell, Miss. Elizabeth
# 11              0      3                     Saundercock, Mr. William Henry
# ...

# %%
df['Age']=='Over 40'
# Out:
# 0       False
# 2       False
# 3       False
# 4       False
# 5        True
# 6       False
# 7       False
# 8       False
# 9       False
# 10       True
# 11      False
# 12      False
# 13      False
# 14       True
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25       True
# 26      False
# 27       True
# 28      False
# 29      False
# 30      False
#         ...
# 1016    False
# 1017    False
# 1018    False
# 1019    False
# 1020     True
# 1021    False
# 1022    False
# 1023    False
# 1024     True
# 1025    False
# 1026     True
# 1027    False
# 1028    False
# 1029    False
# 1030     True
# 1031    False
# 1032    False
# 1033    False
# 1034    False
# 1035    False
# 1036    False
# 1037     True
# 1038    False
# 1039    False
# 1040     True
# 1041    False
# 1042    False
# 1043    False
# 1044    False
# 1045    False
# ...

# %%
df[df['Age']=='Over 40']
# Out:
#       PassengerId  Class                                               Name  \
# 5               0      1                            McCarthy, Mr. Timothy J
# 10              0      1                           Bonnell, Miss. Elizabeth
# 14              0      2                   Hewlett, Mrs. (Mary D Kingcome)
# 25              0      2                              Wheadon, Mr. Edward H
# 27              0      1                     Holverson, Mr. Alexander Oskar
# 38              0      1           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 40              0      1                     Ostby, Mr. Engelhart Cornelius
# 47              0      1                        Harris, Mr. Henry Birkhardt
# 71              0      1                        Chaffee, Mr. Herbert Fuller
# 73              0      3                                  Coxon, Mr. Daniel
# 74              0      1                          Goldschmidt, Mr. George B
# ...

# %%
# dropna means drop null values
df.dropna()
# Out:
#       PassengerId  Class                                               Name  \
# 3               0      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5               0      1                            McCarthy, Mr. Timothy J
# 9               0      3                    Sandstrom, Miss. Marguerite Rut
# 10              0      1                           Bonnell, Miss. Elizabeth
# 18              0      2                              Beesley, Mr. Lawrence
# 20              0      1                       Sloper, Mr. William Thompson
# 23              0      1                     Fortune, Mr. Charles Alexander
# 38              0      1           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 40              0      1                     Ostby, Mr. Engelhart Cornelius
# 47              0      1                        Harris, Mr. Henry Birkhardt
# 49              0      2                       Nye, Mrs. (Elizabeth Ramell)
# ...

# %%
df.dropna(axis =1)
# Out:
#       PassengerId  Class                                               Name  \
# 0               0      3                            Braund, Mr. Owen Harris
# 2               0      3                             Heikkinen, Miss. Laina
# 3               0      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               0      3                           Allen, Mr. William Henry
# 5               0      1                            McCarthy, Mr. Timothy J
# 6               0      3                     Palsson, Master. Gosta Leonard
# 7               0      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8               0      2                Nasser, Mrs. Nicholas (Adele Achem)
# 9               0      3                    Sandstrom, Miss. Marguerite Rut
# 10              0      1                           Bonnell, Miss. Elizabeth
# 11              0      3                     Saundercock, Mr. William Henry
# ...

# %%
df1=df.tail()

# %%
df1
# Out:
#       PassengerId  Class                                             Name  \
# 1041            0      3                        Peacock, Miss. Treasteall
# 1042            0      1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1043            0      3                   Henriksson, Miss. Jenny Lovisa
# 1044            0      1                     Oliva y Ocana, Dona. Fermina
# 1045            0      3                     Saether, Mr. Simon Sivertsen
#
#          Sex       Age  SibSp  Parch              Ticket     Fare Cabin  \
# 1041  female  Under 18      1      1  SOTON/O.Q. 3101315   13.775   NaN
# 1042  female   19 - 40      1      0               19928   90.000   C78
# 1043  female   19 - 40      0      0              347086    7.775   NaN
# 1044  female   19 - 40      0      0            PC 17758  108.900  C105
# 1045    male   19 - 40      0      0  SOTON/O.Q. 3101262    7.250   NaN
#
#      Embarked
# 1041        S
# 1042        Q
# 1043        S
# 1044        C
# ...

# %%
df1.dropna(thresh=2)
# Out:
#       PassengerId  Class                                             Name  \
# 1041            0      3                        Peacock, Miss. Treasteall
# 1042            0      1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1043            0      3                   Henriksson, Miss. Jenny Lovisa
# 1044            0      1                     Oliva y Ocana, Dona. Fermina
# 1045            0      3                     Saether, Mr. Simon Sivertsen
#
#          Sex       Age  SibSp  Parch              Ticket     Fare Cabin  \
# 1041  female  Under 18      1      1  SOTON/O.Q. 3101315   13.775   NaN
# 1042  female   19 - 40      1      0               19928   90.000   C78
# 1043  female   19 - 40      0      0              347086    7.775   NaN
# 1044  female   19 - 40      0      0            PC 17758  108.900  C105
# 1045    male   19 - 40      0      0  SOTON/O.Q. 3101262    7.250   NaN
#
#      Embarked
# 1041        S
# 1042        Q
# 1043        S
# 1044        C
# ...

# %%
df1.dropna(thresh=10)
# Out:
#       PassengerId  Class                                             Name  \
# 1041            0      3                        Peacock, Miss. Treasteall
# 1042            0      1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1043            0      3                   Henriksson, Miss. Jenny Lovisa
# 1044            0      1                     Oliva y Ocana, Dona. Fermina
# 1045            0      3                     Saether, Mr. Simon Sivertsen
#
#          Sex       Age  SibSp  Parch              Ticket     Fare Cabin  \
# 1041  female  Under 18      1      1  SOTON/O.Q. 3101315   13.775   NaN
# 1042  female   19 - 40      1      0               19928   90.000   C78
# 1043  female   19 - 40      0      0              347086    7.775   NaN
# 1044  female   19 - 40      0      0            PC 17758  108.900  C105
# 1045    male   19 - 40      0      0  SOTON/O.Q. 3101262    7.250   NaN
#
#      Embarked
# 1041        S
# 1042        Q
# 1043        S
# 1044        C
# ...

# %%
df1.dropna(thresh=8)
# Out:
#       PassengerId  Class                                             Name  \
# 1041            0      3                        Peacock, Miss. Treasteall
# 1042            0      1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1043            0      3                   Henriksson, Miss. Jenny Lovisa
# 1044            0      1                     Oliva y Ocana, Dona. Fermina
# 1045            0      3                     Saether, Mr. Simon Sivertsen
#
#          Sex       Age  SibSp  Parch              Ticket     Fare Cabin  \
# 1041  female  Under 18      1      1  SOTON/O.Q. 3101315   13.775   NaN
# 1042  female   19 - 40      1      0               19928   90.000   C78
# 1043  female   19 - 40      0      0              347086    7.775   NaN
# 1044  female   19 - 40      0      0            PC 17758  108.900  C105
# 1045    male   19 - 40      0      0  SOTON/O.Q. 3101262    7.250   NaN
#
#      Embarked
# 1041        S
# 1042        Q
# 1043        S
# 1044        C
# ...

# %%
df1.dropna(thresh=8)
# Out:
#       PassengerId  Class                                             Name  \
# 1041            0      3                        Peacock, Miss. Treasteall
# 1042            0      1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1043            0      3                   Henriksson, Miss. Jenny Lovisa
# 1044            0      1                     Oliva y Ocana, Dona. Fermina
# 1045            0      3                     Saether, Mr. Simon Sivertsen
#
#          Sex       Age  SibSp  Parch              Ticket     Fare Cabin  \
# 1041  female  Under 18      1      1  SOTON/O.Q. 3101315   13.775   NaN
# 1042  female   19 - 40      1      0               19928   90.000   C78
# 1043  female   19 - 40      0      0              347086    7.775   NaN
# 1044  female   19 - 40      0      0            PC 17758  108.900  C105
# 1045    male   19 - 40      0      0  SOTON/O.Q. 3101262    7.250   NaN
#
#      Embarked
# 1041        S
# 1042        Q
# 1043        S
# 1044        C
# ...

# %%
df.fillna(value='sudh')
# Out:
#       PassengerId  Class                                               Name  \
# 0               0      3                            Braund, Mr. Owen Harris
# 2               0      3                             Heikkinen, Miss. Laina
# 3               0      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               0      3                           Allen, Mr. William Henry
# 5               0      1                            McCarthy, Mr. Timothy J
# 6               0      3                     Palsson, Master. Gosta Leonard
# 7               0      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8               0      2                Nasser, Mrs. Nicholas (Adele Achem)
# 9               0      3                    Sandstrom, Miss. Marguerite Rut
# 10              0      1                           Bonnell, Miss. Elizabeth
# 11              0      3                     Saundercock, Mr. William Henry
# ...

# %%
df.fillna(value=df['Class'].mean())
# Out:
#       PassengerId  Class                                               Name  \
# 0               0      3                            Braund, Mr. Owen Harris
# 2               0      3                             Heikkinen, Miss. Laina
# 3               0      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               0      3                           Allen, Mr. William Henry
# 5               0      1                            McCarthy, Mr. Timothy J
# 6               0      3                     Palsson, Master. Gosta Leonard
# 7               0      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8               0      2                Nasser, Mrs. Nicholas (Adele Achem)
# 9               0      3                    Sandstrom, Miss. Marguerite Rut
# 10              0      1                           Bonnell, Miss. Elizabeth
# 11              0      3                     Saundercock, Mr. William Henry
# ...

# %%
df['Class']=df['Class'].replace(np.NaN,df['Class'].mean)

# %%
df
# Out:
#       PassengerId  Class                                               Name  \
# 0               0      3                            Braund, Mr. Owen Harris
# 2               0      3                             Heikkinen, Miss. Laina
# 3               0      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               0      3                           Allen, Mr. William Henry
# 5               0      1                            McCarthy, Mr. Timothy J
# 6               0      3                     Palsson, Master. Gosta Leonard
# 7               0      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8               0      2                Nasser, Mrs. Nicholas (Adele Achem)
# 9               0      3                    Sandstrom, Miss. Marguerite Rut
# 10              0      1                           Bonnell, Miss. Elizabeth
# 11              0      3                     Saundercock, Mr. William Henry
# ...

# %% [markdown]
# ##
