# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipcart_url ='https://www.flipkart.com/search?q='+'mobile'

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=mobile'

# %%
uClient =uReq(flipcart_url) # I am asking python to open this url

# %%
uClient

# %%
flipkartPage = uClient.read() # everything on that url page, I am able to fetch

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.9adf7d.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
flipkart_html = bs(flipkartPage, "html.parser")# trying to beutify the above code

# %%
flipkart_html
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})

# %%
bigboxes# to get appropriate class, class here is like model number of mobile for eg
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=mobile&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,4
# ...

# %%
len(bigboxes)
# Out:
# 30

# %%
bigboxes[1]
# Out:
# <div class="_1AtVbE col-12-12"><a class="_1nY1tt" href="/buying-guide/mobiles?sid=tyy,4io&amp;otracker=bg_from_browse_lhs" title="Buying Guide"><div><span>Need help?</span></div><div class="_1mVNvF"><span>Help me decide</span><svg class="ViewtL" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="_2Zt1Py" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><img alt="Buying Guide" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/buying-guide-illustration_4dd325.png"/></a></div>

# %%
box =bigboxes[2]

# %%
url_mobile ='https://www.flipkart.com/search?q' + box.div.div.div.a['href']# extracting actual product

# %%
url_mobile
# Out:
# 'https://www.flipkart.com/search?q/realme-c11-2021-cool-blue-32-gb/p/itmbd856acb97c38?pid=MOBG4BEG3HG78BDG&lid=LSTMOBG4BEG3HG78BDGUWZNDV&marketplace=FLIPKART&q=mobile&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=635a9d4f-5240-43d5-a9f4-84d0bd332ee6.MOBG4BEG3HG78BDG.SEARCH&ppt=None&ppn=None&ssid=6rwc4ja4j40000001647722694324&qH=532c28d5412dd75b'

# %%
# now we want to access all the details of above url_mobile page.
# for that first of all we need to request the url
uClient_mobile=uReq(url_mobile)

# %%
uClient_mobile

# %%
# OR
prodRes = requests.get(url_mobile)
prodRes
# Out:
# <Response [200]>

# %%
prod_html=bs(prodRes.text,'html.parser')

# %%
prod_html
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
review = prod_html.find_all('div', {'class': "_16PBlm"})

# %%
len(review)
# Out:
# 11

# %%
review[0]
# Out:
# <div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Really Nice</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Nice packaging by flipkart n timely delivery 2 days before n nice budgeted  phone in this price range very happy to get this Realme C11 2021 nice antislippery back panel  n big screen size 😀</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202110/blobio-imr-202110_6c9016c353aa40a6b9f51d334dc0faa9.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202110/blobio-imr-202110_6577082d1f3a4370ac47b2f89507aa79.jpg?q=90), url(data:image/svg+xml;base64,...);width:62
# ...

# %%
commentbox=review[0]

# %%
commentbox.div.div.find_all('p',{'class': '_2sc7ZR _2V5EHH'})# p is paragraph
# Out:
# [<p class="_2sc7ZR _2V5EHH">Parikshit Dwivedi</p>]

# %%
commentbox.div.div.div.p.text
# Out:
# 'Really Nice'

# %%
comtag = commentbox.div.div.find_all('div', {'class': ''})

# %%
comtag # inside blank class this comment is available
# Out:
# [<div><div class="">Nice packaging by flipkart n timely delivery 2 days before n nice budgeted  phone in this price range very happy to get this Realme C11 2021 nice antislippery back panel  n big screen size 😀</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">Nice packaging by flipkart n timely delivery 2 days before n nice budgeted  phone in this price range very happy to get this Realme C11 2021 nice antislippery back panel  n big screen size 😀</div>,
#  <div></div>]

# %%
comtag[0].div.text
# Out:
# 'Nice packaging by flipkart n timely delivery 2 days before n nice budgeted  phone in this price range very happy to get this Realme C11 2021 nice antislippery back panel  n big screen size 😀'
